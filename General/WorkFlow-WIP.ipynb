# %% [markdown]
# #Data Science WorkFlow

# %% [markdown]
# From EDA to Reproducibility

# %%
# %matplotlib inline

# %%
import OS
from urllib.request import urlretrieve

URL = "https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD"
def get_fremont_data(filename="Fremont-Bicycle-Counts.csv", url=URL):
        if not os.path.exists(filename):
            urlretrieve(url,filename)
            data = pd.read_csv("Fremont-Bicycle-Counts.csv", index_col="Date", parse_dates=True) 
            return data
#data.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-7569745c9221> in <module>()
# ----> 1 import OS
#       2 from urllib.request import urlretrieve
#       3
#       4 URL = "https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD"
#       5 def get_fremont_data(filename="Fremont-Bicycle-Counts.csv", url=URL):
#
# ImportError: No module named 'OS'

# %%
data = get_fremont_data
data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4f526f957fd7> in <module>()
#       1 data = get_fremont_data
# ----> 2 data()
#
# <ipython-input-7-ddf18c261ed9> in get_fremont_data(filename, url)
#       4 URL = "https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD"
#       5 def get_fremont_data(filename="Fremont-Bicycle-Counts.csv", url=URL):
# ----> 6         if not os.path.exists(filename):
#       7             urlretrieve(url,filename)
#       8             data = pd.read_csv("Fremont-Bicycle-Counts.csv", index_col="Date", parse_dates=True)
#
# NameError: name 'os' is not defined

# %%
urlretrieve(URL, "Fremont-Bicycle-Counts.csv")
# Out:
# ('Fremont-Bicycle-Counts.csv', <http.client.HTTPMessage at 0x878785e7b8>)

# %%
import pandas as pd
data = pd.read_csv("Fremont-Bicycle-Counts.csv") 
data.head()
# Out:
#                      Date  Fremont Bridge West Sidewalk  \
# 0  10/03/2012 12:00:00 AM                           4.0
# 1  10/03/2012 01:00:00 AM                           4.0
# 2  10/03/2012 02:00:00 AM                           1.0
# 3  10/03/2012 03:00:00 AM                           2.0
# 4  10/03/2012 04:00:00 AM                           6.0
#
#    Fremont Bridge East Sidewalk
# 0                           9.0
# 1                           6.0
# 2                           1.0
# 3                           3.0
# 4                           1.0

# %%
data = pd.read_csv("Fremont-Bicycle-Counts.csv", index_col="Date") 
data.head()
# Out:
#                         Fremont Bridge West Sidewalk  \
# Date
# 10/03/2012 12:00:00 AM                           4.0
# 10/03/2012 01:00:00 AM                           4.0
# 10/03/2012 02:00:00 AM                           1.0
# 10/03/2012 03:00:00 AM                           2.0
# 10/03/2012 04:00:00 AM                           6.0
#
#                         Fremont Bridge East Sidewalk
# Date
# 10/03/2012 12:00:00 AM                           9.0
# 10/03/2012 01:00:00 AM                           6.0
# 10/03/2012 02:00:00 AM                           1.0
# 10/03/2012 03:00:00 AM                           3.0
# 10/03/2012 04:00:00 AM                           1.0

# %%
data = pd.read_csv("Fremont-Bicycle-Counts.csv", index_col="Date", parse_dates=True) 
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
data.plot()

# %% [markdown]
# Too much data points to digest!

# %%
# %matplotlib inline
data.resample("M").sum().plot(); # where M means month

# %%
# %matplotlib inline
data.resample("W").sum().plot(); # where W means weeks
